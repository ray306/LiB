# %% [markdown]
# ### Load the corpus

# %%
import numpy as np

corpus_brtext = []
corpus_brtext_test = []
sents_set = set()

with open('br-text.txt') as f:
    for l in f.readlines():
        sents_set.add(l.replace('\n',''))
        
sents_set = list(sents_set)        
sents1 = []
for i in sents_set:
    sent = i.split(' ')
    sents1.append(sent)

for _ in range(400):
    corpus_brtext.append([])
    for i in set(np.random.choice(range(len(sents1)),200)):
        corpus_brtext[-1].append(sents1[i])
    corpus_brtext[-1] = [[''.join(j) for j in corpus_brtext[-1]], corpus_brtext[-1]]

sents2 = []
for i in sents_set[int(len(sents_set)*0.9):]:
    sent = i.split(' ')
    sents2.append(sent)
sents2 = [[''.join(j) for j in sents2], sents2]
corpus_brtext_test.append(sents2)

# %% [markdown]
# ### Run LiB

# %%
import model
import importlib
importlib.reload(model)

model.life = 10
model.max_len = 12
model.memory_in = 0.25
model.memory_out = 0.0001
model.update_rate = 0.2

model.mini_gap = 7
model.use_skip=True

memory = model.TrieList()

corpus_train = corpus_brtext
corpus_test = corpus_brtext_test

model.init(memory, corpus_train[0][0]) # init the Lexicon memory with some unigrams in corpus

for epoch_id in range(5001):
    model.run(epoch_id, memory, corpus_train, corpus_test)
# Out:
# 0	  MemLength: 156
# [B] Precision: 34.58% 	 Recall: 95.12% 	 F1: 50.72%
# [L] Precision: 9.40% 	 Recall: 25.85% 	 F1: 13.78%
#
# 100	  MemLength: 1130
# [B] Precision: 70.26% 	 Recall: 92.07% 	 F1: 79.70%
# [L] Precision: 48.91% 	 Recall: 64.09% 	 F1: 55.48%
#
# 200	  MemLength: 1516
# [B] Precision: 76.28% 	 Recall: 90.75% 	 F1: 82.89%
# [L] Precision: 56.34% 	 Recall: 67.03% 	 F1: 61.22%
#
# 300	  MemLength: 1718
# [B] Precision: 78.70% 	 Recall: 90.63% 	 F1: 84.24%
# [L] Precision: 60.48% 	 Recall: 69.66% 	 F1: 64.75%
#
# 400	  MemLength: 1852
# [B] Precision: 80.13% 	 Recall: 90.52% 	 F1: 85.01%
# [L] Precision: 61.60% 	 Recall: 69.58% 	 F1: 65.35%
#
# 500	  MemLength: 1976
# [B] Precision: 81.17% 	 Recall: 90.25% 	 F1: 85.47%
# [L] Precision: 62.41% 	 Recall: 69.39% 	 F1: 65.71%
#
# 600	  MemLength: 2078
# [B] Precision: 82.05% 	 Recall: 89.67% 	 F1: 85.69%
# [L] Precision: 63.00% 	 Recall: 68.85% 	 F1: 65.79%
#
# 700	  MemLength: 2147
# [B] Precision: 83.01% 	 Recall: 89.09% 	 F1: 85.94%
# [L] Precision: 64.19% 	 Recall: 68.89% 	 F1: 66.46%
#
# 800	  MemLength: 2213
# [B] Precision: 83.01% 	 Recall: 89.78% 	 F1: 86.26%
# [L] Precision: 64.19% 	 Recall: 69.43% 	 F1: 66.70%
#
# 900	  MemLength: 2235
# [B] Precision: 84.50% 	 Recall: 88.62% 	 F1: 86.51%
# [L] Precision: 65.87% 	 Recall: 69.08% 	 F1: 67.43%
#
# 1000	  MemLength: 2296
# [B] Precision: 84.58% 	 Recall: 88.93% 	 F1: 86.70%
# [L] Precision: 66.25% 	 Recall: 69.66% 	 F1: 67.91%
#
# 1100	  MemLength: 2335
# [B] Precision: 84.53% 	 Recall: 88.20% 	 F1: 86.33%
# [L] Precision: 66.10% 	 Recall: 68.96% 	 F1: 67.50%
#
# 1200	  MemLength: 2380
# [B] Precision: 84.17% 	 Recall: 89.51% 	 F1: 86.76%
# [L] Precision: 66.45% 	 Recall: 70.67% 	 F1: 68.49%
#
# 1300	  MemLength: 2421
# [B] Precision: 85.78% 	 Recall: 89.16% 	 F1: 87.44%
# [L] Precision: 68.58% 	 Recall: 71.28% 	 F1: 69.91%
#
# 1400	  MemLength: 2454
# [B] Precision: 84.27% 	 Recall: 87.89% 	 F1: 86.04%
# [L] Precision: 64.53% 	 Recall: 67.30% 	 F1: 65.88%
#
# 1500	  MemLength: 2492
# [B] Precision: 85.40% 	 Recall: 87.62% 	 F1: 86.49%
# [L] Precision: 66.16% 	 Recall: 67.88% 	 F1: 67.01%
#
# 1600	  MemLength: 2520
# [B] Precision: 85.44% 	 Recall: 86.49% 	 F1: 85.96%
# [L] Precision: 65.29% 	 Recall: 66.10% 	 F1: 65.69%
#
# 1700	  MemLength: 2549
# [B] Precision: 85.65% 	 Recall: 86.84% 	 F1: 86.24%
# [L] Precision: 65.42% 	 Recall: 66.33% 	 F1: 65.87%
#
# 1800	  MemLength: 2558
# [B] Precision: 87.55% 	 Recall: 87.89% 	 F1: 87.72%
# [L] Precision: 69.78% 	 Recall: 70.05% 	 F1: 69.91%
#
# 1900	  MemLength: 2566
# [B] Precision: 86.34% 	 Recall: 85.87% 	 F1: 86.11%
# [L] Precision: 65.41% 	 Recall: 65.05% 	 F1: 65.23%
#
# 2000	  MemLength: 2586
# [B] Precision: 86.93% 	 Recall: 88.78% 	 F1: 87.84%
# [L] Precision: 69.69% 	 Recall: 71.17% 	 F1: 70.42%
#
# 2100	  MemLength: 2600
# [B] Precision: 86.58% 	 Recall: 87.38% 	 F1: 86.98%
# [L] Precision: 67.33% 	 Recall: 67.96% 	 F1: 67.64%
#
# 2200	  MemLength: 2602
# [B] Precision: 86.38% 	 Recall: 87.11% 	 F1: 86.74%
# [L] Precision: 67.57% 	 Recall: 68.15% 	 F1: 67.86%
#
# 2300	  MemLength: 2616
# [B] Precision: 86.27% 	 Recall: 88.74% 	 F1: 87.49%
# [L] Precision: 68.36% 	 Recall: 70.32% 	 F1: 69.32%
#
# 2400	  MemLength: 2630
# [B] Precision: 87.19% 	 Recall: 87.19% 	 F1: 87.19%
# [L] Precision: 68.69% 	 Recall: 68.69% 	 F1: 68.69%
#
# 2500	  MemLength: 2647
# [B] Precision: 87.56% 	 Recall: 87.19% 	 F1: 87.38%
# [L] Precision: 69.14% 	 Recall: 68.85% 	 F1: 68.99%
#
# 2600	  MemLength: 2653
# [B] Precision: 86.97% 	 Recall: 87.07% 	 F1: 87.02%
# [L] Precision: 68.30% 	 Recall: 68.38% 	 F1: 68.34%
#
# 2700	  MemLength: 2672
# [B] Precision: 86.83% 	 Recall: 86.76% 	 F1: 86.80%
# [L] Precision: 67.97% 	 Recall: 67.92% 	 F1: 67.94%
#
# 2800	  MemLength: 2691
# [B] Precision: 85.99% 	 Recall: 88.16% 	 F1: 87.06%
# [L] Precision: 68.06% 	 Recall: 69.78% 	 F1: 68.91%
#
# 2900	  MemLength: 2705
# [B] Precision: 86.37% 	 Recall: 86.53% 	 F1: 86.45%
# [L] Precision: 66.43% 	 Recall: 66.56% 	 F1: 66.50%
#
# 3000	  MemLength: 2716
# [B] Precision: 87.36% 	 Recall: 87.96% 	 F1: 87.66%
# [L] Precision: 69.68% 	 Recall: 70.16% 	 F1: 69.92%
#
# 3100	  MemLength: 2721
# [B] Precision: 87.56% 	 Recall: 87.69% 	 F1: 87.63%
# [L] Precision: 69.74% 	 Recall: 69.85% 	 F1: 69.80%
#
# 3200	  MemLength: 2733
# [B] Precision: 87.33% 	 Recall: 87.00% 	 F1: 87.17%
# [L] Precision: 69.15% 	 Recall: 68.89% 	 F1: 69.02%
#
# 3300	  MemLength: 2740
# [B] Precision: 86.71% 	 Recall: 86.61% 	 F1: 86.66%
# [L] Precision: 67.38% 	 Recall: 67.30% 	 F1: 67.34%
#
# 3400	  MemLength: 2754
# [B] Precision: 87.66% 	 Recall: 88.24% 	 F1: 87.95%
# [L] Precision: 70.90% 	 Recall: 71.36% 	 F1: 71.13%
#
# 3500	  MemLength: 2764
# [B] Precision: 85.99% 	 Recall: 86.49% 	 F1: 86.24%
# [L] Precision: 65.99% 	 Recall: 66.37% 	 F1: 66.18%
#
# 3600	  MemLength: 2776
# [B] Precision: 86.79% 	 Recall: 86.73% 	 F1: 86.76%
# [L] Precision: 67.54% 	 Recall: 67.49% 	 F1: 67.52%
#
# 3700	  MemLength: 2787
# [B] Precision: 86.69% 	 Recall: 86.96% 	 F1: 86.82%
# [L] Precision: 67.75% 	 Recall: 67.96% 	 F1: 67.85%
#
# 3800	  MemLength: 2795
# [B] Precision: 87.23% 	 Recall: 86.69% 	 F1: 86.96%
# [L] Precision: 68.15% 	 Recall: 67.72% 	 F1: 67.93%
#
# 3900	  MemLength: 2812
# [B] Precision: 87.49% 	 Recall: 87.96% 	 F1: 87.73%
# [L] Precision: 70.05% 	 Recall: 70.43% 	 F1: 70.24%
#
# 4000	  MemLength: 2816
# [B] Precision: 86.39% 	 Recall: 86.73% 	 F1: 86.56%
# [L] Precision: 66.54% 	 Recall: 66.80% 	 F1: 66.67%
#
# 4100	  MemLength: 2821
# [B] Precision: 86.14% 	 Recall: 86.61% 	 F1: 86.38%
# [L] Precision: 65.90% 	 Recall: 66.25% 	 F1: 66.07%
#
# 4200	  MemLength: 2827
# [B] Precision: 87.58% 	 Recall: 87.04% 	 F1: 87.31%
# [L] Precision: 69.51% 	 Recall: 69.08% 	 F1: 69.29%
#
# 4300	  MemLength: 2832
# [B] Precision: 87.37% 	 Recall: 87.31% 	 F1: 87.34%
# [L] Precision: 69.64% 	 Recall: 69.58% 	 F1: 69.61%
#
# 4400	  MemLength: 2839
# [B] Precision: 87.58% 	 Recall: 87.04% 	 F1: 87.31%
# [L] Precision: 69.04% 	 Recall: 68.61% 	 F1: 68.83%
#
# 4500	  MemLength: 2842
# [B] Precision: 87.17% 	 Recall: 87.54% 	 F1: 87.35%
# [L] Precision: 68.59% 	 Recall: 68.89% 	 F1: 68.74%
#
# 4600	  MemLength: 2858
# [B] Precision: 87.28% 	 Recall: 86.84% 	 F1: 87.06%
# [L] Precision: 68.26% 	 Recall: 67.92% 	 F1: 68.09%
#
# 4700	  MemLength: 2864
# [B] Precision: 86.87% 	 Recall: 88.04% 	 F1: 87.45%
# [L] Precision: 68.73% 	 Recall: 69.66% 	 F1: 69.19%
#
# 4800	  MemLength: 2869
# [B] Precision: 87.49% 	 Recall: 86.30% 	 F1: 86.89%
# [L] Precision: 68.22% 	 Recall: 67.30% 	 F1: 67.76%
#
# 4900	  MemLength: 2869
# [B] Precision: 87.21% 	 Recall: 86.26% 	 F1: 86.73%
# [L] Precision: 67.84% 	 Recall: 67.11% 	 F1: 67.47%
#
# 5000	  MemLength: 2873
# [B] Precision: 86.76% 	 Recall: 86.96% 	 F1: 86.86%
# [L] Precision: 67.64% 	 Recall: 67.80% 	 F1: 67.72%

# %% [markdown]
# ### See the head entities in Lexicon memory

# %%
memory[:50]
# Out:
# [('skipgram', '[bos]', '[eos]'),
#  ('skipgram', '[bos]', 'you'),
#  ('skipgram', '[bos]', 's'),
#  'and',
#  ('skipgram', '[bos]', 'do'),
#  'the',
#  'you',
#  "that's",
#  'it',
#  "it's",
#  'yeah',
#  ('skipgram', '[bos]', 'it'),
#  'youcan',
#  'what',
#  'wanna',
#  'that',
#  'canyou',
#  "he's",
#  ('skipgram', 'look', '[eos]'),
#  ('skipgram', '[bos]', 'i'),
#  'now',
#  ('skipgram', 'a', '[eos]'),
#  "there's",
#  'ithink',
#  'is',
#  'we',
#  "here's",
#  'see',
#  'he',
#  'isthat',
#  ('skipgram', '[bos]', 'c'),
#  ('skipgram', 'and', '[eos]'),
#  'do',
#  "'s",
#  'your',
#  'thisis',
#  'did',
#  'like',
#  'with',
#  'this',
#  'no',
#  ('skipgram', 'it', '[eos]'),
#  'youwanna',
#  "what's",
#  'put',
#  'look',
#  'where',
#  'to',
#  'another',
#  "you're"]

# %%
for k in memory[:200]:
    if k[0] == 'skipgram':
        print(k[1:])
# Out:
# ('[bos]', '[eos]')
# ('[bos]', 'you')
# ('[bos]', 's')
# ('[bos]', 'do')
# ('[bos]', 'it')
# ('look', '[eos]')
# ('[bos]', 'i')
# ('a', '[eos]')
# ('[bos]', 'c')
# ('and', '[eos]')
# ('it', '[eos]')
# ('[bos]', 'an')
# ('[bos]', 'a')
# ('his', '[eos]')
# ('[bos]', 'the')
# ('e', '[eos]')
# ('ok', '[eos]')
# ('the', '[eos]')
# ('you', '[eos]')
# ('this', '[eos]')
# ('re', '[eos]')
# ('wanna', '[eos]')
# ('[bos]', 'put')
# ('isthat', '[eos]')

# %%
for k in memory:
    if k in memory.relationship:
        print(k,memory.relationship[k])
# Out:
# ithink ('skipgram', '[bos]', 'you')
# isthat ('skipgram', '[bos]', 'do')
# another ('skipgram', '[bos]', 'c')
# you're ('skipgram', '[bos]', 's')
# inthe ('skipgram', 'look', '[eos]')
# who ('skipgram', '[bos]', 'do')
# build ('skipgram', '[bos]', 'it')
# smell ('skipgram', 'ok', '[eos]')
# open ('skipgram', '[bos]', '[eos]')
# when ('skipgram', '[bos]', 'you')
# ishe ('skipgram', '[bos]', 's')
# kindof ('skipgram', '[bos]', 'an')
# through ('skipgram', 'look', '[eos]')
# tr ('skipgram', '[bos]', 'i')
# color ('skipgram', '[bos]', 's')
# drink ('skipgram', 'a', '[eos]')
# nice ('skipgram', 'it', '[eos]')
# we'll ('skipgram', '[bos]', 'put')
# pull ('skipgram', '[bos]', 'it')
# think ('skipgram', '[bos]', 'you')
# isthis ('skipgram', '[bos]', 'c')
# push ('skipgram', '[bos]', 'it')
# please ('skipgram', '[bos]', '[eos]')
# daddy's ('skipgram', '[bos]', 's')
# alotof ('skipgram', 'yeah', '[eos]')
# sitdown ('skipgram', 'wanna', '[eos]')
# got ('skipgram', '[bos]', '[eos]')
# dada ('skipgram', '[bos]', '[eos]')
# theboy ('skipgram', '[bos]', '[eos]')
# bring ('skipgram', '[bos]', 'the')
# boy ('skipgram', 'this', '[eos]')
# can't ('skipgram', '[bos]', 'you')
# comb ('skipgram', 'and', '[eos]')
# byebye ('skipgram', '[bos]', 'you')
# am ('skipgram', 're', '[eos]')
# ul ('skipgram', 'a', '[eos]')
# we're ('skipgram', '[bos]', 'gonna')
# getting ('skipgram', '[bos]', 'it')
# turtle ('skipgram', '[bos]', '[eos]')
# judycan ('skipgram', '[bos]', '[eos]')
# taking ('skipgram', '[bos]', 'a')
# any ('skipgram', '[bos]', 'h')
# two ('skipgram', '[bos]', '[eos]')
# books ('skipgram', 'and', '[eos]')
# marie ('skipgram', 'look', '[eos]')
# throw ('skipgram', '[bos]', 'it')
# aboy ('skipgram', 'and', '[eos]')
# andf ('skipgram', '[bos]', 'i')
# may ('skipgram', '[bos]', 'i')
# pepe ('skipgram', 'hi', '[eos]')
# friend ('skipgram', 'little', '[eos]')
# fall ('skipgram', '[bos]', '[eos]')
# en ('skipgram', 're', '[eos]')
# try ('skipgram', '[bos]', 'it')
# andgo ('skipgram', 'it', '[eos]')
# part ('skipgram', 'this', '[eos]')
# toy ('skipgram', '[bos]', 's')
# bed ('skipgram', 'his', '[eos]')
# touch ('skipgram', '[bos]', 'it')
# turn ('skipgram', '[bos]', 'it')
# peter ('skipgram', '[bos]', '[eos]')
# sortof ('skipgram', '[bos]', 'like')
# maybe ('skipgram', '[bos]', 'we')
# bunny's ('skipgram', '[bos]', 's')
# digby ('skipgram', '[bos]', '[eos]')
# watch ('skipgram', '[bos]', 'it')
# youlift ('skipgram', '[bos]', 'this')
# thecat ('skipgram', '[bos]', 's')
# button ('skipgram', '[bos]', '[eos]')
# abunny ('skipgram', 'isee', '[eos]')
# seen ('skipgram', '[bos]', 'an')
# apple ('skipgram', 'the', '[eos]')
# three ('skipgram', 'and', '[eos]')
# playing ('skipgram', 're', '[eos]')
# who'sin ('skipgram', '[bos]', 'that')
# acat ('skipgram', '[bos]', '[eos]')
# whatare ('skipgram', '[bos]', 'the')
# tea ('skipgram', 'some', '[eos]')
# cat ('skipgram', "that'sa", '[eos]')
# closed ('skipgram', 'it', '[eos]')
# ven ('skipgram', 'e', '[eos]')
# shehas ('skipgram', '[bos]', '[eos]')
# you'll ('skipgram', '[bos]', 'put')
# onemore ('skipgram', '[bos]', '[eos]')
# blue ('skipgram', '[bos]', '[eos]')
# aphone ('skipgram', "that's", '[eos]')
# goback ('skipgram', '[bos]', 'to')
# ontopof ('skipgram', '[bos]', 'thisone')
# akiss ('skipgram', 'you', '[eos]')
# monkey ('skipgram', 'a', '[eos]')
# thisdog ('skipgram', 'd', '[eos]')
# came ('skipgram', 'he', '[eos]')
# lena ('skipgram', "where's", '[eos]')
# too ('skipgram', 'that', '[eos]')
# aneleph ('skipgram', '[bos]', 'an')
# i'mnot ('skipgram', '[bos]', 's')
# shall ('skipgram', '[bos]', 'i')
# hungry ('skipgram', '[bos]', '[eos]')
# ful ('skipgram', 'e', '[eos]')
# hug ('skipgram', 'alittle', '[eos]')
# mightbe ('skipgram', '[bos]', 'h')
# ide ('skipgram', 'ar', '[eos]')
# thetoys ('skipgram', 'you', '[eos]')
# will ('skipgram', 'it', 'f')
# annie ('skipgram', 'on', '[eos]')
# aball ('skipgram', '[bos]', '[eos]')
# goodne ('skipgram', '[bos]', 's')
# by ('skipgram', 'ar', '[eos]')
# eatit ('skipgram', 'you', '[eos]')
# okaynow ('skipgram', '[bos]', '[eos]')
# adog ('skipgram', '[bos]', '[eos]')
# agirl ('skipgram', 'and', '[eos]')
# dolly ('skipgram', 'that', '[eos]')
# listen ('skipgram', '[bos]', '[eos]')
# dragon ('skipgram', 'this', '[eos]')
# nothing ('skipgram', '[bos]', '[eos]')
# seven ('skipgram', 'and', '[eos]')
# wait ('skipgram', 'it', '[eos]')
# acall ('skipgram', 'have', '[eos]')
# lse ('skipgram', 'e', '[eos]')
# ze ('skipgram', 'e', '[eos]')
# makeme ('skipgram', '[bos]', '[eos]')
# wh ('skipgram', '[bos]', 'it')
# first ('skipgram', '[bos]', 'you')
# eyes ('skipgram', 'his', '[eos]')
# steak ('skipgram', 'the', '[eos]')
# openit ('skipgram', 'wanna', '[eos]')
# lives ('skipgram', 'who', 'in')
# thering ('skipgram', 'isthat', '[eos]')
# rabbit ('skipgram', 'this', '[eos]')
# anapple ('skipgram', 'isthat', '[eos]')
# myname ('skipgram', '[bos]', 'is')
# meget ('skipgram', '[bos]', 'the')
# bod ('skipgram', 'a', '[eos]')
# paul ('skipgram', '[bos]', 'can')
# doll ('skipgram', 'the', '[eos]')
# called ('skipgram', 'it', '[eos]')
# around ('skipgram', 'it', '[eos]')
# balogn ('skipgram', '[bos]', 'a')
# bye ('skipgram', '[bos]', 'to')
# os ('skipgram', 'i', '[eos]')
# maketwo ('skipgram', '[bos]', 'p')
# isn't ('skipgram', '[bos]', 'he')
# change ('skipgram', '[bos]', 'your')
# bet ('skipgram', 'a', '[eos]')
# okayand ('skipgram', '[bos]', 'how')
# dearso ('skipgram', '[bos]', 'it')
# sleepy ('skipgram', '[bos]', '[eos]')
# bath ('skipgram', '[bos]', '[eos]')
# ready ('skipgram', '[bos]', '[eos]')
# ans ('skipgram', 'e', '[eos]')
# isfor ('skipgram', 'e', '[eos]')
# toys ('skipgram', 'with', '[eos]')
# i'llget ('skipgram', '[bos]', 'you')
# tellhim ('skipgram', '[bos]', 'who')
# knock ('skipgram', '[bos]', 'it')
# he'sgot ('skipgram', '[bos]', '[eos]')
# bowl ('skipgram', 'inthe', '[eos]')
# abowlof ('skipgram', 'isthat', '[eos]')
# table ('skipgram', 'the', '[eos]')
# isn'tit ('skipgram', 'ok', '[eos]')
# balls ('skipgram', 'in', '[eos]')
# next ('skipgram', '[bos]', '[eos]')
# lick ('skipgram', '[bos]', 'you')
# mummy ('skipgram', "it's", '[eos]')
# andthen ('skipgram', '[bos]', 'this')
# nothere ('skipgram', "daddy's", '[eos]')
# givehim ('skipgram', '[bos]', 'a')
# stuck ('skipgram', '[bos]', '[eos]')
# tat ('skipgram', '[bos]', 'a')
# icansee ('skipgram', '[bos]', 'it')
# usually ('skipgram', '[bos]', 'i')
# adragon ('skipgram', "i'm", '[eos]')
# leash ('skipgram', 'a', '[eos]')
# takean ('skipgram', '[bos]', 'a')
# anymore ('skipgram', 'this', '[eos]')
# tape ('skipgram', 'this', '[eos]')
# wayup ('skipgram', '[bos]', 'there')
# ure ('skipgram', 's', '[eos]')
# g@l ('skipgram', '[bos]', '[eos]')
# fix ('skipgram', '[bos]', 'it')
# adoggie ('skipgram', 'and', '[eos]')
# leave ('skipgram', '[bos]', 's')
# youread ('skipgram', '[bos]', 'it')
# inwith ('skipgram', '[bos]', 'thedragon')
# rock ('skipgram', '[bos]', '[eos]')
# seether ('skipgram', '[bos]', 'i')
# ingyour ('skipgram', 'comb', 'hair')
# goahead ('skipgram', '[bos]', '[eos]')
# myhouse ('skipgram', "that's", '[eos]')
# youtook ('skipgram', '[bos]', 'your')
# trucks ('skipgram', 'about', '[eos]')
# somuch ('skipgram', 'it', '[eos]')
# abird ('skipgram', '[bos]', '[eos]')
# drum ('skipgram', 'a', '[eos]')
# pocket ('skipgram', 'his', '[eos]')
# thing ('skipgram', 'e', '[eos]')
# dress ('skipgram', 'your', '[eos]')
# grandma ('skipgram', 'the', '[eos]')
# yourlas ('skipgram', '[bos]', 't')
# dropped ('skipgram', '[bos]', 'it')
# begin ('skipgram', '[bos]', 's')
# juice ('skipgram', '[bos]', '[eos]')
# lookkay ('skipgram', '[bos]', '[eos]')
# wegot ('skipgram', 'what', '[eos]')
# babyget ('skipgram', '[bos]', 'st')
# hellois ('skipgram', '[bos]', 'a')
# andtr ('skipgram', '[bos]', 'i')
# kristin ('skipgram', "where's", '[eos]')
# crying ('skipgram', "he's", '[eos]')
# giveme ('skipgram', '[bos]', 'the')
# raggedy ('skipgram', "where's", '[eos]')
# getyou ('skipgram', "i'm", '[eos]')
# tail ('skipgram', 'his', '[eos]')
# black ('skipgram', '[bos]', 's')
# athome ('skipgram', "'s", '[eos]')
# gra ('skipgram', '[bos]', 'm')
# apuppet ('skipgram', '[bos]', 'm')
# nowi'll ('skipgram', '[bos]', 'do')
# ifound ('skipgram', '[bos]', 'a')
# getit ('skipgram', 'for', '[eos]')
# shoe ('skipgram', '[bos]', '[eos]')
# thisisf ('skipgram', '[bos]', 'i')
# word ('skipgram', 'that', '[eos]')
# wimming ('skipgram', 's', '[eos]')
# andjudy ('skipgram', '[bos]', "'s")
# seeall ('skipgram', '[bos]', 'the')
# kaypaul ('skipgram', '[bos]', "'s")
# z@l ('skipgram', 'a', '[eos]')
# i'dlike ('skipgram', '[bos]', 'it')
# paulput ('skipgram', '[bos]', 's')
# away ('skipgram', 'this', '[eos]')
# dale ('skipgram', '[bos]', '[eos]')
# new ('skipgram', '[bos]', '[eos]')
# takeit ('skipgram', 'wanna', '[eos]')
# comeon ('skipgram', '[bos]', '[eos]')
# kisses ('skipgram', 'and', '[eos]')
# ug ('skipgram', 'm', '[eos]')
# eight ('skipgram', 'and', '[eos]')
# cold ('skipgram', "i'm", '[eos]')
# withtie ('skipgram', '[bos]', 's')
# bunnies ('skipgram', 'about', '[eos]')
# careful ('skipgram', '[bos]', '[eos]')
# seehim ('skipgram', '[bos]', '[eos]')
# gigi' ('skipgram', '[bos]', 's')
# judypat ('skipgram', '[bos]', 's')
# kitten ('skipgram', 'the', '[eos]')
# thatme ('skipgram', '[bos]', 'an')
# favorit ('skipgram', 't', 'e')
# abc@l ('skipgram', '[bos]', '[eos]')
# cookies ('skipgram', '[bos]', '[eos]')
# ineed ('skipgram', '[bos]', 'it')
# toyou ('skipgram', 'them', '[eos]')
# didmom ('skipgram', '[bos]', 'c')
# thekid ('skipgram', '[bos]', 's')
# twokid ('skipgram', '[bos]', 's')
# hisear ('skipgram', '[bos]', 's')
# puppies ('skipgram', "they're", '[eos]')
# alion ('skipgram', '[bos]', '[eos]')
# carry ('skipgram', '[bos]', 'you')
# mouth ('skipgram', 'his', '[eos]')
# nopo ('skipgram', '[bos]', 'p')
# crayons ('skipgram', '[bos]', '[eos]')
# grammy ('skipgram', 'you', '[eos]')
# pace ('skipgram', 's', '[eos]')
# i'lllet ('skipgram', '[bos]', 'you')
# wecando ('skipgram', 'what', '[eos]')
# hurt ('skipgram', "i'm", '[eos]')
# nodon't ('skipgram', '[bos]', 'pull')
# d@lfor ('skipgram', '[bos]', 'daddy')
# 'sface ('skipgram', 'thedog', '[eos]')
# kitties ('skipgram', 'the', '[eos]')
# hangup ('skipgram', 'wanna', '[eos]')
# car ('skipgram', 'the', '[eos]')
# letgo ('skipgram', '[bos]', '[eos]')
# theydig ('skipgram', '[bos]', 'the')
# hole ('skipgram', 'the', '[eos]')
# took ('skipgram', '[bos]', "mommy's")
# gig ('skipgram', '[bos]', 'i')
# theball ('skipgram', 'get', '[eos]')
# atower ('skipgram', "that's", '[eos]')
# whathas ('skipgram', '[bos]', 'it')
# i'lleat ('skipgram', '[bos]', 'your')
# seethem ('skipgram', 'and', '[eos]')
# hiding ('skipgram', 'his', '[eos]')
# ringing ('skipgram', "'s", '[eos]')
# howsoft ('skipgram', 'look', '[eos]')
# mustbe ('skipgram', '[bos]', 'c')
# hereshe ('skipgram', '[bos]', 'is')
# herbook ('skipgram', 'ing', '[eos]')
# susie ('skipgram', 'with', '[eos]')
# hishead ('skipgram', 'on', '[eos]')
# umbrell ('skipgram', '[bos]', 'a')
# wish ('skipgram', 'you', '[eos]')
# mother ('skipgram', "'s", '[eos]')
# babyis ('skipgram', 'your', '[eos]')
# abcs ('skipgram', 'about', '[eos]')
# feels ('skipgram', 'that', '[eos]')
# before ('skipgram', 'this', '[eos]')
# isthatn ('skipgram', '[bos]', 'an')
# nowe ('skipgram', '[bos]', 'm')
# nothose ('skipgram', '[bos]', 'are')
# forget ('skipgram', '[bos]', 'it')
# thegirl ('skipgram', 'and', '[eos]')
# coffee ('skipgram', '[bos]', 'c')
# mama ('skipgram', 'with', '[eos]')
# askhim ('skipgram', '[bos]', 'what')
# while ('skipgram', 'alittle', '[eos]')
# whatame ('skipgram', '[bos]', 's')
# nd ('skipgram', 'hi', '[eos]')
# numbers ('skipgram', 'about', '[eos]')
# hands ('skipgram', 'ing', '[eos]')
# ste ('skipgram', '[bos]', 'a')
# cows ('skipgram', 'seethe', '[eos]')
# scratch ('skipgram', '[bos]', '[eos]')
# andwich ('skipgram', 's', '[eos]')
# zipping ('skipgram', 'for', '[eos]')
# he'sso ('skipgram', '[bos]', '[eos]')
# lollipo ('skipgram', '[bos]', 'p')
# doeshef ('skipgram', '[bos]', 'it')
# reach ('skipgram', '[bos]', 'inthere')
# onlysee ('skipgram', 'i', '[eos]')
# yeswith ('skipgram', '[bos]', 'mommy')
# onlytwo ('skipgram', '[bos]', '[eos]')
# acup ('skipgram', 'and', '[eos]')
# howdoes ('skipgram', '[bos]', 'he')
# piggy ('skipgram', '[bos]', '[eos]')
# either ('skipgram', 'that', '[eos]')
# aper ('skipgram', 'i', '[eos]')
# onetwo ('skipgram', '[bos]', '[eos]')
# les ('skipgram', 'i', '[eos]')
# higher ('skipgram', '[bos]', '[eos]')
# uncle ('skipgram', '[bos]', 'm')
# food ('skipgram', '[bos]', '[eos]')
# mypants ('skipgram', '[bos]', 'are')
# dro ('skipgram', '[bos]', 'p')
# pauland ('skipgram', '[bos]', '[eos]')
# dogbark ('skipgram', '[bos]', 's')
# imighth ('skipgram', '[bos]', 'a')
# aves ('skipgram', 'c', '[eos]')
# ouse ('skipgram', 'them', '[eos]')
# tolift ('skipgram', '[bos]', 'that')
# yellow ('skipgram', '[bos]', '[eos]')
# i'mlone ('skipgram', '[bos]', 'some')
# ich ('skipgram', '[bos]', 'a')
# orange ('skipgram', 'and', '[eos]')
# alldone ('skipgram', '[bos]', '[eos]')
# nothank ('skipgram', '[bos]', 'you')
# holdon ('skipgram', '[bos]', '[eos]')
# lock ('skipgram', 'c', '[eos]')
# soft ('skipgram', '[bos]', '[eos]')
# bigbite ('skipgram', 'a', '[eos]')
# bubbles ('skipgram', 'the', '[eos]')
# kisshim ('skipgram', '[bos]', '[eos]')
# hot ('skipgram', '[bos]', '[eos]')
# ost ('skipgram', 'm', '[eos]')
# cover ('skipgram', 'onthe', '[eos]')
# fouro' ('skipgram', '[bos]', 'c')
# stoeat ('skipgram', 'like', '[eos]')
# adrum ('skipgram', 'want', '[eos]')
# game ('skipgram', 'alittle', '[eos]')
# icould ('skipgram', '[bos]', 'go')
# ach ('skipgram', 're', '[eos]')
# asmile ('skipgram', '[bos]', 'it')
# arms ('skipgram', 'his', '[eos]')
# strange ('skipgram', '[bos]', 'do')
# rosey ('skipgram', '[bos]', '[eos]')
# cowyes ('skipgram', '[bos]', 'whatelse')
# duck ('skipgram', '[bos]', 's')
# green ('skipgram', '[bos]', '[eos]')
# onefor ('skipgram', 'and', '[eos]')
# hairand ('skipgram', '[bos]', 'whatelse')
# cheer ('skipgram', '[bos]', 'i')
# adiaper ('skipgram', 'for', '[eos]')
# toobad ('skipgram', '[bos]', 'we')
# vens ('skipgram', 'a', '[eos]')
# onthere ('skipgram', 'that', '[eos]')
# apage ('skipgram', 'd', '[eos]')
# broke ('skipgram', 'is', 'n')
# youdoit ('skipgram', 'now', '[eos]')
# andmake ('skipgram', '[bos]', 'are')
# beach ('skipgram', 'the', '[eos]')
# tree ('skipgram', 'onthe', '[eos]')
# yarn ('skipgram', "that's", '[eos]')
# callit ('skipgram', 'to', '[eos]')
# sides ('skipgram', 'the', '[eos]')
# ahole ('skipgram', '[bos]', '[eos]')
# cupor ('skipgram', '[bos]', 'm')
# uphere ('skipgram', '[bos]', '[eos]')
# bite ('skipgram', 'a', '[eos]')
# sback ('skipgram', 'other', '[eos]')
# houl ('skipgram', 'is', 'd')
# it'sapi ('skipgram', '[bos]', 'c')
# a@lb@l ('skipgram', '[bos]', 'c')
# nonot ('skipgram', '[bos]', 'to')
# quack ('skipgram', '[bos]', '[eos]')
# girl ('skipgram', 'the', '[eos]')
# foryou ('skipgram', 'them', '[eos]')
# hidaddy ('skipgram', '[bos]', '[eos]')
# closeit ('skipgram', 'wanna', '[eos]')
# pink ('skipgram', 'it', '[eos]')
# train ('skipgram', '[bos]', '[eos]')
# thumb ('skipgram', 'your', '[eos]')
# min ('skipgram', 'i', '[eos]')
# bowland ('skipgram', 'the', 'it')
# ana@l ('skipgram', 'isthat', '[eos]')
# nowsee ('skipgram', '[bos]', '[eos]')
# abox ('skipgram', 'in', '[eos]')
# jelly ('skipgram', '[bos]', '[eos]')
# zoo ('skipgram', 'the', '[eos]')
# arabbit ('skipgram', 'and', '[eos]')
# ween ('skipgram', 't', 'phone')
# azebra ('skipgram', 'and', '[eos]')
# icecu ('skipgram', '[bos]', 'be')
# i'llsee ('skipgram', '[bos]', 'you')
# wood ('skipgram', '[bos]', '[eos]')
# tome ('skipgram', 'it', '[eos]')
# sgood ('skipgram', 'smell', '[eos]')
# situp ('skipgram', 'wanna', '[eos]')
# nonotqu ('skipgram', '[bos]', 'it')
# sister ('skipgram', 'your', '[eos]')
# eleanor ('skipgram', 'to', '[eos]')
# whale ('skipgram', 'a', '[eos]')
# milk ('skipgram', 'with', '[eos]')
# ons ('skipgram', 'i', '[eos]')
# aring ('skipgram', '[bos]', '[eos]')
# rent ('skipgram', 'e', '[eos]')
# tofeed ('skipgram', "that's", '[eos]')
# acomb ('skipgram', 'and', '[eos]')
# wake ('skipgram', 'a', '[eos]')
# onthem ('skipgram', 'down', '[eos]')
# ontop ('skipgram', 'them', '[eos]')
# swing ('skipgram', '[bos]', '[eos]')
# himim ('skipgram', '[bos]', 'i')
# boywith ('skipgram', '[bos]', 'a')
# mydaddy ('skipgram', '[bos]', '[eos]')
# noteven ('skipgram', '[bos]', "mommy's")
# twodog ('skipgram', '[bos]', 's')
# thisboy ('skipgram', '[bos]', '[eos]')
# arm ('skipgram', 'your', '[eos]')
# isitfor ('skipgram', '[bos]', 'you')
# six ('skipgram', 'and', '[eos]')
# abrush ('skipgram', 'and', '[eos]')
# adoll ('skipgram', 'isthat', '[eos]')
# dinner ('skipgram', '[bos]', '[eos]')
# hername ('skipgram', '[bos]', 'is')
# abug ('skipgram', 'isee', '[eos]')
# harder ('skipgram', '[bos]', 'dragon')
# feedme ('skipgram', '[bos]', '[eos]')
# ier ('skipgram', 'r', 'and')
# anduten ('skipgram', '[bos]', 's')
# where'd ('skipgram', '[bos]', 'thedoggie')
# seethat ('skipgram', '[bos]', 'little')
# ice ('skipgram', 'u', '[eos]')
# nhis ('skipgram', 'the', '[eos]')
# mayispe ('skipgram', '[bos]', 'a')
# shuth ('skipgram', '[bos]', 'i')
# jello ('skipgram', '[bos]', 's')
# hishand ('skipgram', 'in', '[eos]')
# key ('skipgram', 'on', '[eos]')
# puppet ('skipgram', 'the', '[eos]')
# hasred ('skipgram', '[bos]', 's')
# inever ('skipgram', '[bos]', 's')
# fish ('skipgram', '[bos]', '[eos]')
# walking ('skipgram', "they're", '[eos]')
# len ('skipgram', '[bos]', 'a')
# amonkey ('skipgram', "that's", '[eos]')
# sayopen ('skipgram', '[bos]', 'that')
# self ('skipgram', 'your', '[eos]')
# vacuum ('skipgram', "that'sa", '[eos]')
# knees ('skipgram', 'his', '[eos]')
# theyall ('skipgram', '[bos]', 'fell')
# iswhat ('skipgram', '[bos]', '[eos]')
# aminute ('skipgram', 'it', '[eos]')
# hiseyes ('skipgram', "where's", '[eos]')
# y@l ('skipgram', '[bos]', '[eos]')
# cklace ('skipgram', 'e', '[eos]')
# babies ('skipgram', 'for', '[eos]')
# zipper ('skipgram', 'the', '[eos]')
# byed ('skipgram', '[bos]', 'a')
# thebest ('skipgram', 'that', '[eos]')
# bel ('skipgram', 'a', '[eos]')
# aspoon ('skipgram', 'with', '[eos]')
# andnot ('skipgram', '[bos]', 'thisone')
# irmouth ('skipgram', 'inthe', '[eos]')
# wannano ('skipgram', '[bos]', 'it')
# shoesh ('skipgram', '[bos]', 'o')
# cage ('skipgram', 'the', '[eos]')
# lin ('skipgram', 'o', '[eos]')
# mycage ('skipgram', 'in', '[eos]')
# rang ('skipgram', '[bos]', 'the')
# foot ('skipgram', "'s", '[eos]')
# anditis ('skipgram', '[bos]', 'an')
# mirror ('skipgram', 'this', '[eos]')
# supper ('skipgram', 'his', '[eos]')
# theyfly ('skipgram', '[bos]', '[eos]')
# gator ('skipgram', 'i', '[eos]')
# bottom ('skipgram', 'the', '[eos]')
# thatway ('skipgram', 'on', '[eos]')
# birds ('skipgram', 'some', '[eos]')
# atwork ('skipgram', "he's", '[eos]')
# five ('skipgram', '[bos]', '[eos]')
# daisies ('skipgram', '[bos]', '[eos]')
# already ('skipgram', 'a', '[eos]')
# andcomb ('skipgram', '[bos]', '[eos]')
# waitnow ('skipgram', '[bos]', 'i')
# pretend ('skipgram', '[bos]', '[eos]')
# onmy ('skipgram', 'talk', 'telephone')
# obieis ('skipgram', '[bos]', 'a')
# lunch ('skipgram', 'his', '[eos]')
# bang ('skipgram', '[bos]', 'them')
# ahat ('skipgram', "it's", '[eos]')
# raisins ('skipgram', 'look', '[eos]')
# yesthey ('skipgram', '[bos]', 'are')
# dadabye ('skipgram', '[bos]', '[eos]')
# thehole ('skipgram', 'through', '[eos]')
# goon ('skipgram', '[bos]', '[eos]')
# avacuum ('skipgram', "that's", '[eos]')
# theend ('skipgram', 'e', '[eos]')
# abc ('skipgram', '[bos]', 's')
# andthre ('skipgram', '[bos]', 'w')
# number ('skipgram', 'e', '[eos]')
# ves ('skipgram', 'a', '[eos]')
# pantson ('skipgram', 'his', '[eos]')
# hegoes ('skipgram', 'e', '[eos]')
# sort ('skipgram', 'some', '[eos]')
# init ('skipgram', 'putthedoggie', '[eos]')
# mess ('skipgram', 'a', '[eos]')
# horse ('skipgram', '[bos]', '[eos]')
# bless ('skipgram', '[bos]', 'you')
# que ('skipgram', 'i', '[eos]')
# ye ('skipgram', 'e', '[eos]')
# soup ('skipgram', '[bos]', '[eos]')
# higramp ('skipgram', '[bos]', 's')
# saysee ('skipgram', '[bos]', 'you')
# stongue ('skipgram', 'it', '[eos]')
# amousie ('skipgram', 'isee', '[eos]')
# histail ('skipgram', "where's", '[eos]')
# hisears ('skipgram', 'thoseare', '[eos]')
# best ('skipgram', 'the', '[eos]')
# tosmell ('skipgram', 's', '[eos]')
# picture ('skipgram', 'this', '[eos]')
# oneatat ('skipgram', '[bos]', 'i')
# alap ('skipgram', '[bos]', 'to')
# great ('skipgram', "that's", '[eos]')
# bridge ('skipgram', 'a', '[eos]')
# withaqu ('skipgram', '[bos]', 'i')
# scooby ('skipgram', 'd', '[eos]')
# yourdog ('skipgram', 'd', '[eos]')
# mat ('skipgram', '[bos]', 'the')
# ahorse ('skipgram', "that's", '[eos]')
# itfor ('skipgram', 'is', 'n')
# straps ('skipgram', 'little', '[eos]')
# goodfor ('skipgram', '[bos]', 'you')
# snap ('skipgram', 'the', '[eos]')
# myvoice ('skipgram', '[bos]', 'is')
# justfor ('skipgram', '[bos]', 'you')
# handin ('skipgram', 'your', '[eos]')
# setoys ('skipgram', 'the', '[eos]')
# asec ('skipgram', 'on', '[eos]')
# astrap ('skipgram', '[bos]', 'yeah')
# guess ('skipgram', '[bos]', 'who')
# hestay ('skipgram', '[bos]', 's')
# snow ('skipgram', "that's", '[eos]')
# box ('skipgram', '[bos]', '[eos]')
# ziplat ('skipgram', 'to', 'e')
# floor ('skipgram', 'the', '[eos]')
# onannie ('skipgram', '[bos]', "'s")
# truck ('skipgram', '[bos]', 's')
# ronger ('skipgram', 't', 'e')
# olin ('skipgram', 'i', '[eos]')
# ball ('skipgram', '[bos]', 's')
# jellybe ('skipgram', '[bos]', 'an')
# ntine ('skipgram', 'e', '[eos]')
# that'sn ('skipgram', '[bos]', 'an')
# gorgeou ('skipgram', '[bos]', 's')
# andsee ('skipgram', '[bos]', 'you')
# uppies ('skipgram', 'p', '[eos]')
# member ('skipgram', 'e', '[eos]')
# nope ('skipgram', '[bos]', '[eos]')
# d@l ('skipgram', '[bos]', '[eos]')
# wbook ('skipgram', 'e', '[eos]')
# sone ('skipgram', 'want', '[eos]')
# ipulle ('skipgram', '[bos]', 'do')
# violin ('skipgram', 'a', '[eos]')
# awake ('skipgram', "he's", '[eos]')
# theymat ('skipgram', '[bos]', 'c')
# dapperd ('skipgram', '[bos]', 'an')
# ver ('skipgram', 'e', '[eos]')
# scott ('skipgram', 'isthat', '[eos]')
# maybete ('skipgram', '[bos]', 'a')
# carkey ('skipgram', '[bos]', 's')
# neakers ('skipgram', 's', '[eos]')
# andmar ('skipgram', '[bos]', 's')
# lion ('skipgram', '[bos]', 's')
# ffinman ('skipgram', 'u', '[eos]')
# h@l ('skipgram', '[bos]', 'i')
# morning ('skipgram', 'this', '[eos]')
# helook ('skipgram', '[bos]', 's')
# ade ('skipgram', 'ar', '[eos]')
# wantsay ('skipgram', '[bos]', 'goodbye')
# airpl ('skipgram', '[bos]', 'an')
# lap ('skipgram', '[bos]', '[eos]')
# feedit ('skipgram', '[bos]', 'to')
# inste ('skipgram', '[bos]', 'a')
# gus ('skipgram', '[bos]', '[eos]')
# kfast ('skipgram', 'a', '[eos]')
# anele ('skipgram', '[bos]', 'p')
# ush ('skipgram', 'm', '[eos]')
# dothey ('skipgram', 'smell', '[eos]')
# ldren ('skipgram', 'i', '[eos]')
# veon ('skipgram', 'a', '[eos]')
# kee ('skipgram', '[bos]', 'p')
# ommy ('skipgram', 'them', '[eos]')
# themall ('skipgram', 'say', '[eos]')
# rying ('skipgram', 'c', '[eos]')
# oops ('skipgram', 'p', '[eos]')
# awalk ('skipgram', 'for', '[eos]')
# eye ('skipgram', 'and', '[eos]')
# kid ('skipgram', 'it', '[eos]')
# re ('skipgram', 'ishe', '[eos]')
# onkey ('skipgram', 'them', '[eos]')
# wich ('skipgram', 'and', '[eos]')
# icanget ('skipgram', '[bos]', 'you')
# sock ('skipgram', '[bos]', '[eos]')
# note ('skipgram', '[bos]', 've')
# pants ('skipgram', 'his', '[eos]')
# derful ('skipgram', 'on', '[eos]')
# thepant ('skipgram', '[bos]', 's')
# imal ('skipgram', 'an', '[eos]')
# ither ('skipgram', 'e', '[eos]')
# dres ('skipgram', '[bos]', 's')
# tout ('skipgram', 'e', '[eos]')
# goodjob ('skipgram', '[bos]', '[eos]')
# gue ('skipgram', '[bos]', 's')
# chom ('skipgram', '[bos]', 'p')
# abow ('skipgram', 'isthat', '[eos]')
# apiece ('skipgram', '[bos]', '[eos]')
# aving ('skipgram', 'h', 't')
# okayzip ('skipgram', '[bos]', 'it')
# tata's ('skipgram', 'comb', 'hair')
# lytwo ('skipgram', 'on', '[eos]')
# rose ('skipgram', '[bos]', 's')
# biteb ('skipgram', '[bos]', 'it')
# dadah ('skipgram', '[bos]', 'i')
# tyours ('skipgram', 'r', 'e')
# hiscott ('skipgram', '[bos]', '[eos]')
# apper ('skipgram', 'd', '[eos]')
# ilkin ('skipgram', 'them', '[eos]')
# kaboo ('skipgram', 'e', '[eos]')
# onto ('skipgram', '[bos]', 'p')
# pancake ('skipgram', '[bos]', 's')
# areful ('skipgram', 'c', '[eos]')
# dear ('skipgram', '[bos]', 's')
# waynow ('skipgram', 'a', '[eos]')
# vy ('skipgram', 'a', '[eos]')
# babydo ('skipgram', '[bos]', 'it')
# laces ('skipgram', 'e', '[eos]')
# tter ('skipgram', 'e', '[eos]')
# rabb ('skipgram', 'the', 'it')
# whatel ('skipgram', '[bos]', 's')
# aggedy ('skipgram', 'r', 'and')
# kis ('skipgram', '[bos]', 's')
# thank ('skipgram', '[bos]', 'you')
# nicekis ('skipgram', '[bos]', 's')
# kisse ('skipgram', '[bos]', 's')
# owl ('skipgram', '[bos]', 's')
# pus ('skipgram', '[bos]', 'h')
# ubbles ('skipgram', 'theb', '[eos]')
# pyou ('skipgram', 'l', '[eos]')
# chcolor ('skipgram', 'i', '[eos]')
# tiger ('skipgram', '[bos]', 's')
# aisies ('skipgram', 'd', '[eos]')
# isies ('skipgram', 'a', '[eos]')
# ightw ('skipgram', 'r', 'e')
# llplay ('skipgram', "'", 'a')
# n'tta ('skipgram', 'do', 'k')
# cubes ('skipgram', 'e', '[eos]')
# dalice ('skipgram', 'e', '[eos]')
# nitup ('skipgram', 'e', '[eos]')
# wearit ('skipgram', 'i', '[eos]')
# cehoney ('skipgram', 'i', '[eos]')
# leone ('skipgram', 'i', '[eos]')
# untieit ('skipgram', 'i', '[eos]')
# nsils ('skipgram', 'e', '[eos]')
# cecream ('skipgram', 'i', '[eos]')
# swesaw ('skipgram', 'l', '[eos]')
# ammi ('skipgram', 'r', 'e')
# keokay ('skipgram', 'i', '[eos]')
# pbaby ('skipgram', 'l', '[eos]')
# tterone ('skipgram', 'e', '[eos]')
# licious ('skipgram', 'e', '[eos]')
# leover ('skipgram', 'i', '[eos]')
# ggs ('skipgram', 'e', '[eos]')
# hpaul ('skipgram', 'it', '[eos]')
# hidada ('skipgram', '[bos]', '[eos]')
# aturtle ('skipgram', 'and', '[eos]')
# ukelele ('skipgram', 'and', '[eos]')
# evening ('skipgram', 'this', '[eos]')
# vening ('skipgram', 'e', '[eos]')
# medoit ('skipgram', '[bos]', '[eos]')
# hiswhat ('skipgram', '[bos]', '[eos]')
# yare ('skipgram', 'the', '[eos]')
# nwhat ('skipgram', 'the', '[eos]')
# iseehim ('skipgram', '[bos]', '[eos]')
# mynose ('skipgram', '[bos]', '[eos]')
# ately ('skipgram', 'l', '[eos]')
# balloon ('skipgram', '[bos]', '[eos]')
# blueone ('skipgram', 'this', '[eos]')
# aboat ('skipgram', '[bos]', '[eos]')
# again ('skipgram', 'look', '[eos]')
# ls ('skipgram', 'e', '[eos]')
# outokay ('skipgram', 'get', '[eos]')
# cutey ('skipgram', '[bos]', '[eos]')
# beeis ('skipgram', '[bos]', 'for')
# andtwo ('skipgram', '[bos]', '[eos]')
# quickly ('skipgram', '[bos]', '[eos]')
# seover ('skipgram', 'the', '[eos]')
# blockgo ('skipgram', 'the', '[eos]')
# mydoor ('skipgram', '[bos]', '[eos]')
# toast ('skipgram', '[bos]', '[eos]')
# andfour ('skipgram', '[bos]', '[eos]')
# leokay ('skipgram', 'i', '[eos]')
# andeye ('skipgram', '[bos]', '[eos]')
# whoami ('skipgram', 'and', '[eos]')
# apuppy ('skipgram', "where's", '[eos]')
# sherry ('skipgram', '[bos]', '[eos]')
# thecup ('skipgram', '[bos]', '[eos]')
# notatoy ('skipgram', '[bos]', '[eos]')
# sameway ('skipgram', 'the', '[eos]')
# trains ('skipgram', 'e', '[eos]')
# lyone ('skipgram', 'on', '[eos]')
# jacket ('skipgram', 'his', '[eos]')
# cture ('skipgram', 'i', '[eos]')
# zebra ('skipgram', 'a', '[eos]')
# tofthe ('skipgram', 'ar', '[eos]')
# ibbon ('skipgram', 'ar', '[eos]')
# tumbled ('skipgram', '[bos]', '[eos]')
# putitup ('skipgram', '[bos]', '[eos]')
# ourboat ('skipgram', "where's", '[eos]')
# bucky ('skipgram', '[bos]', '[eos]')
# andkite ('skipgram', '[bos]', '[eos]')
# bigbird ('skipgram', '[bos]', '[eos]')
# wheels ('skipgram', '[bos]', '[eos]')
# notyet ('skipgram', '[bos]', '[eos]')
# ldalice ('skipgram', 'i', '[eos]')
# white ('skipgram', '[bos]', '[eos]')
# utiful ('skipgram', 'a', '[eos]')
# kaylook ('skipgram', '[bos]', '[eos]')
# doggy ('skipgram', '[bos]', '[eos]')
# anson ('skipgram', 'e', '[eos]')
# anddraw ('skipgram', '[bos]', '[eos]')
# myapple ('skipgram', "where's", '[eos]')
# andone ('skipgram', '[bos]', 'for')
# tingout ('skipgram', 'get', '[eos]')
# letdigb ('skipgram', '[bos]', 'you')
# ms ('skipgram', 'ar', '[eos]')
# amelia ('skipgram', 'this', '[eos]')
# hisfeet ('skipgram', 'on', '[eos]')
# spoon ('skipgram', 'the', '[eos]')
# twomore ('skipgram', '[bos]', '[eos]')
# twoeyes ('skipgram', '[bos]', '[eos]')
# lane ('skipgram', 'the', '[eos]')
# diapers ('skipgram', 'his', '[eos]')
# adoor ('skipgram', 'with', '[eos]')
# cowgo ('skipgram', 'the', '[eos]')
# funbook ('skipgram', 'a', '[eos]')
# leg ('skipgram', 'your', '[eos]')
# ling ('skipgram', 'ar', '[eos]')
# andants ('skipgram', 'e', '[eos]')
# socrazy ('skipgram', 'get', '[eos]')
# tomommy ('skipgram', 'them', '[eos]')
# aclock ('skipgram', '[bos]', '[eos]')
# myshoe ('skipgram', '[bos]', '[eos]')
# ose ('skipgram', 'o', '[eos]')
# hisback ('skipgram', 'on', '[eos]')
# sixwhat ('skipgram', '[bos]', '[eos]')
# itsnose ('skipgram', "where's", '[eos]')
# lf ('skipgram', 'e', '[eos]')
# acarrot ('skipgram', '[bos]', '[eos]')
# @lisred ('skipgram', 'them', '[eos]')
# amouse ('skipgram', '[bos]', '[eos]')
# andh@l ('skipgram', '[bos]', '[eos]')
# enegg ('skipgram', 're', '[eos]')
# iaper ('skipgram', 'd', '[eos]')
# erful ('skipgram', 'd', '[eos]')
# awatch ('skipgram', 'with', '[eos]')
# limbup ('skipgram', 'c', '[eos]')
# seelook ('skipgram', '[bos]', '[eos]')
# b@l ('skipgram', '[bos]', '[eos]')
# thistoy ('skipgram', 'with', '[eos]')
# awhile ('skipgram', 'for', '[eos]')
# nowhat ('skipgram', '[bos]', '[eos]')
# andsix ('skipgram', '[bos]', '[eos]')
# thekiss ('skipgram', 'for', '[eos]')
# allset ('skipgram', '[bos]', '[eos]')
# ownhair ('skipgram', 'your', '[eos]')
# thisway ('skipgram', 'it', '[eos]')
# enumber ('skipgram', 'it', '[eos]')
# zippers ('skipgram', 'and', '[eos]')
# quid ('skipgram', 'i', '[eos]')
# vyjump ('skipgram', 'a', '[eos]')
# theduck ('skipgram', "where's", '[eos]')
# brother ('skipgram', 'your', '[eos]')
# nicejob ('skipgram', '[bos]', '[eos]')
# bedroom ('skipgram', 'your', '[eos]')
# i'mhere ('skipgram', '[bos]', '[eos]')
# saymama ('skipgram', '[bos]', '[eos]')
# boat ('skipgram', '[bos]', '[eos]')
# allback ('skipgram', 'them', '[eos]')
# youlena ('skipgram', 'for', '[eos]')
# ernie ('skipgram', 'and', '[eos]')
# toohard ('skipgram', 'isthat', '[eos]')
# later ('skipgram', 'for', '[eos]')
# lseokay ('skipgram', 'e', '[eos]')
# oneboy ('skipgram', '[bos]', '[eos]')
# andnine ('skipgram', '[bos]', '[eos]')
# noway ('skipgram', '[bos]', '[eos]')
# egg ('skipgram', '[bos]', '[eos]')
# nowdoit ('skipgram', '[bos]', '[eos]')
# findher ('skipgram', '[bos]', '[eos]')
# lyout ('skipgram', 'e', '[eos]')
# alemon ('skipgram', 'isthat', '[eos]')
# herdoll ('skipgram', 'with', '[eos]')
# fungame ('skipgram', 'a', '[eos]')
# fixhim ('skipgram', '[bos]', '[eos]')
# verheis ('skipgram', 'e', '[eos]')
# yagain ('skipgram', 'and', '[eos]')
# ttoday ('skipgram', 'e', '[eos]')
# yourtoe ('skipgram', 'get', '[eos]')
# asnap ('skipgram', '[bos]', '[eos]')
# andpaul ('skipgram', '[bos]', '[eos]')
# notay@l ('skipgram', '[bos]', '[eos]')
# findtwo ('skipgram', '[bos]', '[eos]')
# nomore ('skipgram', '[bos]', '[eos]')
# petme ('skipgram', 'wanna', '[eos]')
# mie ('skipgram', 'm', '[eos]')
# adaddy ('skipgram', 'isthat', '[eos]')
# ese ('skipgram', 'e', '[eos]')
# faraway ('skipgram', 'a', '[eos]')
# usic ('skipgram', 'm', '[eos]')
# cheeks ('skipgram', 'your', '[eos]')
# wayout ('skipgram', 'the', '[eos]')
# ikeokay ('skipgram', 'them', '[eos]')
# circles ('skipgram', 'in', '[eos]')
# himthat ('skipgram', 'd', '[eos]')
# newtoys ('skipgram', '[bos]', '[eos]')
# achick ('skipgram', "it's", '[eos]')
# umbo ('skipgram', 'd', '[eos]')
# tworose ('skipgram', '[bos]', 's')
# inwhat ('skipgram', '[bos]', '[eos]')
# hisbed ('skipgram', 'in', '[eos]')
# arling ('skipgram', 'd', '[eos]')
# bathtub ('skipgram', 'inthe', '[eos]')
# lla ('skipgram', 'e', '[eos]')
# roses ('skipgram', 'seethe', '[eos]')
# stoodup ('skipgram', 'you', '[eos]')
# kone ('skipgram', 'in', '[eos]')
# ababy ('skipgram', 'isthat', '[eos]')
# ontoday ('skipgram', 'i', '[eos]')
# adaisy ('skipgram', 'and', '[eos]')
# leaveon ('skipgram', '[bos]', '[eos]')
# neat ('skipgram', '[bos]', '[eos]')
# fishie ('skipgram', 'a', '[eos]')
# atruck ('skipgram', 'isthat', '[eos]')
# mymeat ('skipgram', 'for', '[eos]')
# jill ('skipgram', 'and', '[eos]')
# knee ('skipgram', "'s", '[eos]')
# ggybank ('skipgram', 'i', '[eos]')
# patthem ('skipgram', 'and', '[eos]')
# afish ('skipgram', 'e', '[eos]')
# thelane ('skipgram', 'down', '[eos]')
# iron ('skipgram', '[bos]', '[eos]')
# waketoo ('skipgram', 'a', '[eos]')
# ourwhat ('skipgram', 'to', '[eos]')
# myturn ('skipgram', '[bos]', '[eos]')
# akitten ('skipgram', 'isee', '[eos]')
# water ('skipgram', 'the', '[eos]')
# dressed ('skipgram', 'get', '[eos]')
# bags ('skipgram', 'three', '[eos]')
# hiellie ('skipgram', '[bos]', '[eos]')
# grandpa ('skipgram', 'to', '[eos]')
# bug ('skipgram', '[bos]', '[eos]')
# words ('skipgram', 'the', '[eos]')
# c@lis ('skipgram', 'and', '[eos]')
# bbit ('skipgram', 'a', '[eos]')
# raccoon ('skipgram', '[bos]', '[eos]')
# tryit ('skipgram', 'wanna', '[eos]')
# atbig ('skipgram', 're', '[eos]')
# boyyeah ('skipgram', '[bos]', '[eos]')
# szipper ('skipgram', 'it', '[eos]')
# liquid ('skipgram', "it's", '[eos]')
# apurse ('skipgram', 'isthat', '[eos]')
# ance ('skipgram', 'd', '[eos]')
# pileone ('skipgram', '[bos]', '[eos]')
# 'shair ('skipgram', 'a', '[eos]')
# oftear ('skipgram', 'as', '[eos]')
# jamason ('skipgram', 'a', '[eos]')
# tummy ('skipgram', "'s", '[eos]')
# peach ('skipgram', 'a', '[eos]')
# aleash ('skipgram', 'with', '[eos]')
# isitnan ('skipgram', '[bos]', '[eos]')
# isy ('skipgram', 'a', '[eos]')
# waving ('skipgram', 're', '[eos]')
# iseeone ('skipgram', '[bos]', '[eos]')
# alacing ('skipgram', '[bos]', '[eos]')
# hiscage ('skipgram', 'in', '[eos]')
# kiddo ('skipgram', 'it', '[eos]')
# theart ('skipgram', 'e', '[eos]')
# pullup ('skipgram', '[bos]', '[eos]')
# alone ('skipgram', 'you', '[eos]')
# ctures ('skipgram', 'i', '[eos]')
# shirt ('skipgram', 'his', '[eos]')
# sobig ('skipgram', '[bos]', '[eos]')
# hicindy ('skipgram', '[bos]', '[eos]')
# cycle ('skipgram', 'i', '[eos]')
# gotonit ('skipgram', 'it', '[eos]')
# hisneck ('skipgram', '[bos]', '[eos]')
# castle ('skipgram', 'the', '[eos]')
# pear ('skipgram', 'a', '[eos]')
# eateat ('skipgram', '[bos]', '[eos]')
# suphere ('skipgram', 'open', '[eos]')
# hisbath ('skipgram', 'in', '[eos]')
# poke ('skipgram', '[bos]', '[eos]')
# i'mnice ('skipgram', '[bos]', '[eos]')
# garden ('skipgram', '[bos]', '[eos]')
# melia ('skipgram', "that'sa", '[eos]')
# tomama ('skipgram', 'it', '[eos]')
# yeslena ('skipgram', '[bos]', '[eos]')
# allgone ('skipgram', '[bos]', '[eos]')
# hiannie ('skipgram', '[bos]', '[eos]')
# awhat ('skipgram', '[bos]', '[eos]')
# onlyone ('skipgram', '[bos]', '[eos]')
# peek ('skipgram', '[bos]', '[eos]')
# belongs ('skipgram', 'it', '[eos]')
# dapper ('skipgram', '[bos]', '[eos]')
# i'mout ('skipgram', '[bos]', '[eos]')
# hishat ('skipgram', "it's", '[eos]')
# cupokay ('skipgram', '[bos]', '[eos]')
# myteeth ('skipgram', 'look', '[eos]')
# mine ('skipgram', "'s", '[eos]')
# soff ('skipgram', 'the', '[eos]')
# mousie ('skipgram', 'a', '[eos]')
# pinkone ('skipgram', 'the', '[eos]')
# aribbon ('skipgram', '[bos]', '[eos]')
# yeahhi ('skipgram', '[bos]', '[eos]')
# ftero@l ('skipgram', 'a', '[eos]')
# kite ('skipgram', 'a', '[eos]')
# at@l ('skipgram', '[bos]', '[eos]')
# humpty ('skipgram', '[bos]', '[eos]')
# brain ('skipgram', 'onthe', '[eos]')
# nowwait ('skipgram', '[bos]', '[eos]')
# herhair ('skipgram', 'in', '[eos]')
# ggysays ('skipgram', 'i', '[eos]')
# atelena ('skipgram', 'd', '[eos]')
# bert ('skipgram', '[bos]', '[eos]')
# avy ('skipgram', 'he', '[eos]')
# denough ('skipgram', 'u', '[eos]')
# @lright ('skipgram', 'c', '[eos]')
# heese ('skipgram', 'c', '[eos]')
# rophone ('skipgram', 'c', '[eos]')
# avyjump ('skipgram', 'he', '[eos]')
# i'mcold ('skipgram', '[bos]', '[eos]')
# sweet ('skipgram', 'smell', '[eos]')
# 'smine ('skipgram', 'thisone', '[eos]')
# feet ('skipgram', 'little', '[eos]')
# uppet ('skipgram', 'm', '[eos]')
# saysoon ('skipgram', 'he', '[eos]')
# ovesee ('skipgram', 'm', '[eos]')
# nohi ('skipgram', '[bos]', '[eos]')
# andwant ('skipgram', '[bos]', '[eos]')
# wayhere ('skipgram', 'onthe', '[eos]')
# oving ('skipgram', 'm', '[eos]')
# machine ('skipgram', 'that', '[eos]')
# atching ('skipgram', 'c', '[eos]')
# etheend ('skipgram', 'it', '[eos]')
# andacup ('skipgram', 'yeah', '[eos]')
# looksee ('skipgram', '[bos]', '[eos]')
# wayhigh ('skipgram', '[bos]', '[eos]')
# abugyes ('skipgram', '[bos]', '[eos]')
# arthat ('skipgram', 'he', '[eos]')
# saybye ('skipgram', '[bos]', '[eos]')
# bigger ('skipgram', 'a', '[eos]')
# agic ('skipgram', 'm', '[eos]')
# wasacow ('skipgram', 'that', '[eos]')
# atdoing ('skipgram', 'c', '[eos]')
# arit ('skipgram', 'he', '[eos]')
# ream ('skipgram', 'c', '[eos]')
# tomimi ('skipgram', 'hi', '[eos]')
# builtup ('skipgram', 'them', '[eos]')
# upyeah ('skipgram', "'s", '[eos]')
# oira ('skipgram', 'm', '[eos]')
# atter ('skipgram', 'them', '[eos]')
# atchit ('skipgram', 'c', '[eos]')
# poorboy ('skipgram', 'that', '[eos]')
# amefrom ('skipgram', 'c', '[eos]')
# earis ('skipgram', "thedoggie's", '[eos]')
# aride ('skipgram', 'for', '[eos]')
# blowtoo ('skipgram', '[bos]', '[eos]')
# moving ('skipgram', "he's", '[eos]')
# youokay ('skipgram', 'with', '[eos]')
# hisnose ('skipgram', "it's", '[eos]')
# whoitis ('skipgram', "that's", '[eos]')
# andaboy ('skipgram', '[bos]', '[eos]')
# m@lfor ('skipgram', "what's", '[eos]')
# free ('skipgram', "he's", '[eos]')
# awhale ('skipgram', "it's", '[eos]')
# horsie ('skipgram', 'onthe', '[eos]')
# callup ('skipgram', '[bos]', '[eos]')
# sawit ('skipgram', 'you', '[eos]')
# wrist ('skipgram', "where'syour", '[eos]')
# sockoff ('skipgram', 'your', '[eos]')
# socks ('skipgram', 'your', '[eos]')
# locks ('skipgram', 'c', '[eos]')
# ajar ('skipgram', "that's", '[eos]')
# asteak ('skipgram', "that's", '[eos]')
# lovely ('skipgram', "that's", '[eos]')
# nasays ('skipgram', 'she', '[eos]')
# quiver ('skipgram', 'it', '[eos]')
# pread ('skipgram', 's', '[eos]')
# hibaby ('skipgram', '[bos]', '[eos]')
# himarie ('skipgram', '[bos]', '[eos]')
# orning ('skipgram', 'them', '[eos]')
# magic ('skipgram', "that's", '[eos]')
# wall ('skipgram', 'onthe', '[eos]')
# quirrel ('skipgram', 's', '[eos]')
# careyou ('skipgram', 's', '[eos]')
# illyone ('skipgram', 's', '[eos]')
# c@ltoo ('skipgram', 'a', '[eos]')
# @ltoo ('skipgram', 'c', '[eos]')
# acookie ('skipgram', "that's", '[eos]')
# hisname ('skipgram', "what's", '[eos]')
# uchi ('skipgram', 's', '[eos]')
# hmallow ('skipgram', 's', '[eos]')
# darling ('skipgram', 'isee', '[eos]')
# ac@ltoo ('skipgram', 'with', '[eos]')
# abutton ('skipgram', "that's", '[eos]')
# als ('skipgram', 'and', '[eos]')
# @ld@l ('skipgram', 'c', '[eos]')
# avens ('skipgram', 'he', '[eos]')
# ils ('skipgram', 's', '[eos]')
# allup ('skipgram', 'it', '[eos]')
# forhim ('skipgram', 'look', '[eos]')
# amatter ('skipgram', "what's", '[eos]')
# park ('skipgram', 'the', '[eos]')
# atsay ('skipgram', 'c', '[eos]')
# aorange ('skipgram', "that's", '[eos]')
# breakit ('skipgram', 'and', '[eos]')
# indian ('skipgram', '[bos]', '[eos]')
# hibob ('skipgram', '[bos]', '[eos]')
# thelion ('skipgram', 'with', '[eos]')
# wayin ('skipgram', 'onthe', '[eos]')
# shaving ('skipgram', "he's", '[eos]')
# akite ('skipgram', 'with', '[eos]')
# ahouse ('skipgram', "that's", '[eos]')
# hiszip ('skipgram', 'about', '[eos]')
# sohigh ('skipgram', "that's", '[eos]')
# 'sup ('skipgram', 'thisone', '[eos]')
# forus ('skipgram', 'e', '[eos]')
# tdragon ('skipgram', 'e', '[eos]')
# redible ('skipgram', 'c', '[eos]')
# thepage ('skipgram', 'open', '[eos]')
# saucers ('skipgram', 'and', '[eos]')
# aucers ('skipgram', 's', '[eos]')
# hardone ('skipgram', 'a', '[eos]')
# alright ('skipgram', "that's", '[eos]')
# andals ('skipgram', 's', '[eos]')
# thee@l ('skipgram', "what's", '[eos]')
# diaper ('skipgram', 'your', '[eos]')
# boyhas ('skipgram', 'that', '[eos]')
# wasgood ('skipgram', 'that', '[eos]')
# ablack ('skipgram', "that's", '[eos]')
# vecups ('skipgram', 'i', '[eos]')
# arehere ('skipgram', 'that', '[eos]')
# wannago ('skipgram', '[bos]', '[eos]')
# herhand ('skipgram', 'in', '[eos]')
# animals ('skipgram', 'little', '[eos]')
# issygo ('skipgram', 's', '[eos]')
# awall ('skipgram', 'on', '[eos]')
# upmarie ('skipgram', 'you', '[eos]')
# theg@l ('skipgram', "'s", '[eos]')
# mybook ('skipgram', '[bos]', '[eos]')
# au@l ('skipgram', "that's", '[eos]')
# sweater ('skipgram', "where'syour", '[eos]')
# zygo ('skipgram', 'u', '[eos]')
# anumber ('skipgram', "that's", '[eos]')
# theyarn ('skipgram', 'with', '[eos]')
# rayon ('skipgram', 'c', '[eos]')
# ane@l ('skipgram', "that's", '[eos]')
# pyeah ('skipgram', 'a', '[eos]')
# ak@l ('skipgram', "that's", '[eos]')
# ldhave ('skipgram', 'u', '[eos]')
# cheese ('skipgram', '[bos]', '[eos]')
# himtoo ('skipgram', 'ing', '[eos]')
# goout ('skipgram', 's', '[eos]')
# hipepe ('skipgram', '[bos]', '[eos]')
# byeyes ('skipgram', 'is', '[eos]')
# nicenow ('skipgram', 's', '[eos]')
# uzygo ('skipgram', 's', '[eos]')
# purple ('skipgram', "that's", '[eos]')
# instead ('skipgram', '[bos]', '[eos]')
# inokay ('skipgram', 'get', '[eos]')
# poles ('skipgram', 'ing', '[eos]')
# anowl ('skipgram', "that's", '[eos]')
# hateit ('skipgram', 'you', '[eos]')
# adogtoo ('skipgram', "that's", '[eos]')
# outlets ('skipgram', 'little', '[eos]')
# ftersix ('skipgram', 'a', '[eos]')
# toalice ('skipgram', 'k', '[eos]')
# touchme ('skipgram', '[bos]', '[eos]')
# tohim ('skipgram', 'hi', '[eos]')
# nearby ('skipgram', "i'm", '[eos]')
# herlake ('skipgram', 'in', '[eos]')
# parade ('skipgram', 'inthe', '[eos]')
# yuntie ('skipgram', 'seethe', '[eos]')
# formilk ('skipgram', '[bos]', '[eos]')
# andfive ('skipgram', '[bos]', '[eos]')
# anegg ('skipgram', "that's", '[eos]')
# itin ('skipgram', 'youwant', '[eos]')
# lippers ('skipgram', 's', '[eos]')
# alicehi ('skipgram', 'hi', '[eos]')
# bark ('skipgram', 'gonna', '[eos]')
# p@lonit ('skipgram', 'a', '[eos]')
# h@li@l ('skipgram', '[bos]', '[eos]')
# ople ('skipgram', 'e', '[eos]')
# dance ('skipgram', 'him', '[eos]')
# ittens ('skipgram', 'm', '[eos]')
# teeth ('skipgram', 'some', '[eos]')
# thesnap ('skipgram', "that's", '[eos]')
# breeze ('skipgram', 'inthe', '[eos]')
# hyface ('skipgram', 'c', '[eos]')
# thattoo ('skipgram', 'ing', '[eos]')
# ingbook ('skipgram', 'touch', '[eos]')
# wings ('skipgram', 's', '[eos]')
# popout ('skipgram', '[bos]', '[eos]')
# bell ('skipgram', 'the', '[eos]')
# windows ('skipgram', 'and', '[eos]')
# bows ('skipgram', 'some', '[eos]')
# youany ('skipgram', 'have', '[eos]')
# aktoyou ('skipgram', 'e', '[eos]')
# anyface ('skipgram', 'have', '[eos]')
# tofit ('skipgram', 's', '[eos]')
# adrink ('skipgram', 'have', '[eos]')
# minute ('skipgram', '[bos]', '[eos]')
# spanked ('skipgram', 's', '[eos]')
# wakeup ('skipgram', 'to', '[eos]')
# ttime ('skipgram', 's', '[eos]')
# biteyou ('skipgram', 'goingto', '[eos]')
# morrow ('skipgram', 'to', '[eos]')
# verthem ('skipgram', 'to', '[eos]')
# hthem ('skipgram', 'c', '[eos]')
# mach ('skipgram', 'to', '[eos]')
# gotoday ('skipgram', 'daddy', '[eos]')
# rginia ('skipgram', 'i', '[eos]')
# ickokay ('skipgram', 'k', '[eos]')
# mittens ('skipgram', 'your', '[eos]')
# days ('skipgram', 'in', '[eos]')
# yawn ('skipgram', 'y', '[eos]')
# olk ('skipgram', 'y', '[eos]')
# 'sleash ('skipgram', 'thedog', '[eos]')
# lophone ('skipgram', 'y', '[eos]')
# thread ('skipgram', 'the', '[eos]')
# fducks ('skipgram', 'to', '[eos]')
# doittoo ('skipgram', 'to', '[eos]')
# duckies ('skipgram', 'howmany', '[eos]')
# remove ('skipgram', 'to', '[eos]')
# ants ('skipgram', 'little', '[eos]')
# match ('skipgram', 'that', '[eos]')
# withit ('skipgram', 'have', '[eos]')
# clock ('skipgram', "where'sthe", '[eos]')
# yourarm ('skipgram', 'over', '[eos]')
# rug ('skipgram', 'thisisa', '[eos]')
# nf@l ('skipgram', 'thisisa', '[eos]')
# aletter ('skipgram', "that's", '[eos]')
# fixit ('skipgram', 'to', '[eos]')
# himback ('skipgram', 'want', '[eos]')
# n'tyou ('skipgram', 'have', '[eos]')
# acrayon ('skipgram', "that's", '[eos]')
# yeslook ('skipgram', '[bos]', '[eos]')
# mehoney ('skipgram', 'i', '[eos]')
# anl@l ('skipgram', "that's", '[eos]')
# hbox ('skipgram', 'c', '[eos]')
# backup ('skipgram', 'it', '[eos]')
# donext ('skipgram', 'to', '[eos]')
# keon ('skipgram', 'i', '[eos]')
# iseekay ('skipgram', '[bos]', '[eos]')
# ickson ('skipgram', 't', '[eos]')
# hearher ('skipgram', 'you', '[eos]')
# fixthat ('skipgram', 'ican', '[eos]')
# inabox ('skipgram', 'puthim', '[eos]')
# monster ('skipgram', 'he', '[eos]')
# kers ('skipgram', 'is', '[eos]')
# trained ('skipgram', 's', '[eos]')
# doggies ('skipgram', 'little', '[eos]')
# abite ('skipgram', 'thedoggie', '[eos]')
# beard ('skipgram', "daddy's", '[eos]')
# reven ('skipgram', 'e', '[eos]')
# myshoes ('skipgram', '[bos]', '[eos]')
# outyet ('skipgram', 'going', '[eos]')
# hiagain ('skipgram', 'say', '[eos]')
# ourse ('skipgram', 'c', '[eos]')
# outnow ('skipgram', 'thedoggie', '[eos]')
# af@lfor ('skipgram', '[bos]', '[eos]')
# engine ('skipgram', 're', '[eos]')
# hikay ('skipgram', '[bos]', '[eos]')
# ametime ('skipgram', 's', '[eos]')
# snows ('skipgram', 'it', '[eos]')
# thereis ('skipgram', 'whatelse', '[eos]')
# dher ('skipgram', 'in', '[eos]')
# hertape ('skipgram', 'e', '[eos]')
# ans@l ('skipgram', '[bos]', '[eos]')
# kethis ('skipgram', 'i', '[eos]')
# retoday ('skipgram', 'to', '[eos]')
# top ('skipgram', 'onthe', '[eos]')
# p@l ('skipgram', 'a', '[eos]')
# apig ('skipgram', 'that', '[eos]')

# %% [markdown]
# ### See the chunk segmentation result and the subchunk segmentation result

# %%
article, article_raw = corpus_train[2]
onset, end = 10, 20
print('---\nchunks\n---')
model.show_result(memory, article_raw[onset:end], article[onset:end], decompose=False)
print('---\nsubchunks\n---')
model.show_result(memory, article_raw[onset:end], article[onset:end], decompose=True)
# Out:
# ---
# chunks
# ---
#  	 can you 	 make 	 a tower 	 with 	 what you 	 have
#  	 canyou 	 make 	 atower 	 with 	 whatyou 	 have
#
# you can 	 get down 	 by 	 yourself 	 see she has 	 her
# youcan 	 getdown 	 b y 	 your self 	 seeshehas 	 her
#
# pajamas 	 on 	 don't 	 honey 	 you'll 	 break 	 it
# p a j am as 	 on 	 don't 	 honey 	 you 'll 	 br eak 	 it
#
# numbers 	 are those 	 slippers 	 no what 	 that's a
# numbers 	 arethose 	 s l i pper s 	 now hat 	 that'sa
#
# ---
# subchunks
# ---
#  	 can you 	 make 	 a tower 	 with 	 what 	 you
#  	 canyou 	 make 	 atower 	 with 	 what 	 you
#
# have 	 you can 	 get 	 down 	 by 	 yourself
# have 	 youcan 	 get 	 down 	 b y 	 your self
#
# see she has 	 her 	 pajamas 	 on 	 don't 	 honey
# seeshehas 	 her 	 p a j am as 	 on 	 don't 	 honey
#
# you'll 	 break 	 it 	 numbers 	 are 	 those 	 slippers
# you 'll 	 br eak 	 it 	 numbers 	 are 	 those 	 s l i p per s
#
# no what 	 that's 	 a 	 bird 	 which 	 color
# now h at 	 that's 	 a 	 bird 	 which 	 color
